# %%
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# # Context
#
# In `make_synthetic_questions.ipynb`, we generated synthetic questions to bootstrap evaluation of the retrieval system in our hardware store's Q&A system.
#
# This notebook shows the first step in calculating precision and recall with different retrieval parameters. We will run more advanced experiments in future notebooks after we have these baseline scores.
#
# ## Data
#
# Here is a brief review of the data.

# %%
import json
import lancedb
import os
import pandas as pd
from typing import List, Dict
from concurrent.futures import ThreadPoolExecutor

pd.set_option("display.max_colwidth", 160)

db = lancedb.connect("./lancedb")
reviews_table = db.open_table("reviews")
reviews_table.to_pandas().head()
# Out:
#   id   product_title  \
# 0  0  Cordless Drill
# 1  1  Cordless Drill
# 2  2  Cordless Drill
# 3  3  Cordless Drill
# 4  4  Cordless Drill
#
#                                                                                                                                                product_description  \
# 0  This lightweight cordless drill offers a powerful performance with adjustable speed settings, perfect for various drilling tasks. Its ergonomic design provi...
# 1  This lightweight cordless drill offers a powerful performance with adjustable speed settings, perfect for various drilling tasks. Its ergonomic design provi...
# 2  This lightweight cordless drill offers a powerful performance with adjustable speed settings, perfect for various drilling tasks. Its ergonomic design provi...
# 3  This lightweight cordless drill offers a powerful performance with adjustable speed settings, perfect for various drilling tasks. Its ergonomic design provi...
# 4  This lightweight cordless drill offers a powerful performance with adjustable speed settings, perfect for various drilling tasks. Its ergonomic design provi...
#
#                                                                                                                                                             review  \
# 0  I've been using this cordless drill for over a year now on various home improvement projects and it hasn't let me down once. The adjustable speed settings m...
# 1  This cordless drill is a gem! It's extremely lightweight, which is a big plus when working on overhead projects. The ergonomic grip is comfortable, even dur...
# 2  I bought this drill for my DIY projects around the house, and it was one of the best investments. It's got a nice weight balance that's neither too heavy no...
# 3  As a professional contractor, I rely on durable and efficient tools. This cordless drill exceeds my expectations. It's powerful enough to drive screws into ...
# 4  This cordless drill packs a punch for its size. I've used it for everything from installing shelves to building a deck. The torque settings are easy to adju...
#
#                                                                                                                                                             vector
# 0  [0.010204377, 0.020264247, 0.028945748, -0.016862787, -0.0016243078, -0.00039148735, 0.008103476, 0.0564242, 0.030168494, 0.006058154, 0.022832016, 0.002653...
# 1  [0.02122662, 0.019065969, -0.025120541, -0.013474393, 0.022568123, 0.016881574, -0.023482246, 0.07916057, 0.04140853, -0.016703498, 0.005677646, 0.000275460...
# 2  [-0.01990977, 0.026872814, -0.010510256, -0.03597374, 0.01943203, -0.031029142, -0.014833793, 0.08374763, 0.018440722, -0.0010569973, 0.03501826, -0.0019079...
# 3  [0.020162972, -0.00025912662, 0.013526903, -0.0020457166, 0.014242676, 0.0125442315, -0.029237522, 0.05240917, 0.013551166, -0.012641286, 0.048818167, -0.00...
# 4  [-0.029100286, 0.00055905356, -0.024061428, -0.004820546, 0.024710461, 0.020910667, -0.007528784, 0.0724557, 0.009393279, 0.00724557, 0.019506395, 0.0220081...

# %%
with open("synthetic_eval_dataset.json", "r") as f:
    synthetic_questions = json.load(f)
synthetic_questions
# Out:
# [{'question': 'How long does the battery last on this cordless drill before needing a recharge?',
#   'answer': 'The battery lasts a good 4-5 hours of continuous use before needing a recharge.',
#   'chunk_id': '0'},
#  {'question': 'Can this cordless drill handle tough materials?',
#   'answer': 'Yes, it is versatile enough to handle tough materials like concrete.',
#   'chunk_id': '0'},
#  {'question': 'Is this cordless drill easy to handle for overhead work?',
#   'answer': "Yes, it's extremely lightweight, which is a big plus when working on overhead projects.",
#   'chunk_id': '1'},
#  {'question': 'What features come with this drill?',
#   'answer': 'The set includes two batteries, a charger, and a handy carrying case.',
#   'chunk_id': '1'},
#  {'question': "How's the weight balance on this cordless drill?",
#   'answer': "The cordless drill has a nice weight balance that's neither too heavy nor too light.",
#   'chunk_id': '2'},
#  {'question': 'What about the speed control on this drill?',
#   'answer': 'The drill features a variable speed motor that responds quickly to pressure changes, making it very intuitive to use.',
#   'chunk_id': '2'},
#  {'question': 'How durable and reliable is this cordless drill?',
#   'answer': 'The cordless drill is noted for its durability and efficiency, with consistent and reliable battery life and power delivery.',
#   'chunk_id': '3'},
#  {'question': 'What features make this drill suitable for working in dimly lit areas?',
#   'answer': 'The drill includes an LED light, which is a great addition for working in dimly lit areas.',
#   'chunk_id': '3'},
#  {'question': 'How does the cordless drill perform in tight spaces?',
#   'answer': 'The compact design allows it to fit into tight spaces, which is very helpful.',
#   'chunk_id': '4'},
#  {'question': 'What are some features of the torque settings on this drill?',
#   'answer': 'The torque settings are easy to adjust and offer a lot of range.',
#   'chunk_id': '4'},
#  {'question': 'How easy is it to handle this cordless drill?',
#   'answer': 'The ergonomic design provides comfort during prolonged use, making it easy to handle.',
#   'chunk_id': '5'},
#  {'question': 'Is the drill durable enough for heavy use?',
#   'answer': 'The drill has a fan that keeps it cool during heavy use and has proven durable since it still works well even after being dropped.',
#   'chunk_id': '5'},
#  {'question': 'How fast does the battery charge on this cordless drill?',
#   'answer': 'The battery charges in about 45 minutes, which is quicker than expected.',
#   'chunk_id': '6'},
#  {'question': 'What materials can you drill through with this cordless drill?',
#   'answer': 'You can drill through metal, wood, and plastic with no issues.',
#   'chunk_id': '6'},
#  {'question': 'How does this cordless drill handle speed control?',
#   'answer': 'The speed control is seamless, allowing for precise and powerful drilling.',
#   'chunk_id': '7'},
#  {'question': 'What safety features does this cordless drill have?',
#   'answer': 'It has an immediate brake that stops the drill bit when the trigger is released, along with additional safety features.',
#   'chunk_id': '7'},
#  {'question': 'How good is the battery life on this cordless drill?',
#   'answer': 'The battery life is excellent.',
#   'chunk_id': '8'},
#  {'question': 'Is it comfortable to use for long periods?',
#   'answer': 'Yes, the ergonomic design prevents hand cramps even after hours of use.',
#   'chunk_id': '8'},
#  {'question': "How's the torque on this cordless drill?",
#   'answer': 'The torque is fantastic.',
#   'chunk_id': '9'},
#  {'question': 'What cool features does this drill have for changing bits?',
#   'answer': 'The quick-release chuck makes changing bits effortless.',
#   'chunk_id': '9'},
#  {'question': 'How long does the battery last on this cordless drill?',
#   'answer': 'The high-capacity lithium-ion battery lasts a long time, allowing for numerous projects without needing to recharge.',
#   'chunk_id': '10'},
#  {'question': 'Is this cordless drill good for tight spaces?',
#   'answer': 'Yes, its compact size makes it easy to maneuver in tight spaces.',
#   'chunk_id': '10'},
#  {'question': 'How well does the battery perform on this cordless drill?',
#   'answer': 'The lithium-ion battery holds a charge exceptionally well, even after continuous use for a couple of hours.',
#   'chunk_id': '11'},
#  {'question': 'Is the cordless drill easy to use in tight spaces?',
#   'answer': 'Yes, the compact design allows it to get into small areas with ease.',
#   'chunk_id': '11'},
#  {'question': 'How does the battery performance of this drill hold up?',
#   'answer': 'The high-capacity battery allows the drill to maintain power while drilling through concrete, wood, and metal.',
#   'chunk_id': '12'},
#  {'question': 'What features make this cordless drill suitable for detailed work?',
#   'answer': 'Its compact size is perfect for detailed woodwork, and the integrated LED light helps to illuminate dark corners.',
#   'chunk_id': '12'},
#  {'question': 'How long can the battery last on this cordless drill?',
#   'answer': 'The battery life is impressive, allowing for multiple projects on a single charge.',
#   'chunk_id': '13'},
#  {'question': 'What features make this cordless drill easy to use?',
#   'answer': 'Its compact size makes it easy to hold and control, and the bright LED light is useful for hard-to-see spots.',
#   'chunk_id': '13'},
#  {'question': 'How long can I use the cordless drill on a single charge?',
#   'answer': "The high-capacity lithium-ion battery ensures that you don't have to frequently recharge, even during intense use.",
#   'chunk_id': '14'},
#  {'question': 'Is this cordless drill easy to handle?',
#   'answer': 'The compact design makes it comfortable to hold, allowing for easier maneuverability.',
#   'chunk_id': '14'},
#  {'question': 'How long does the battery last for this cordless drill?',
#   'answer': 'The lithium-ion battery lasts through multiple drilling and screwing tasks without needing a recharge.',
#   'chunk_id': '15'},
#  {'question': 'What features make this drill suitable for tight spaces?',
#   'answer': 'Its compact size allows for excellent control and easier maneuverability.',
#   'chunk_id': '15'},
#  {'question': 'How long does the battery last on this cordless drill?',
#   'answer': 'The high-capacity battery lasts surprisingly long, rarely resulting in worries about running out of power.',
#   'chunk_id': '16'},
#  {'question': 'Is this drill easy to handle, especially in tight spaces?',
#   'answer': 'Yes, its compact design allows for easier maneuverability and reduces fatigue, making it suitable for narrow, dark areas.',
#   'chunk_id': '16'},
#  {'question': 'How long does the battery last on this cordless drill?',
#   'answer': 'The lithium-ion battery provides a long-lasting charge, which is essential for extended projects.',
#   'chunk_id': '17'},
#  {'question': 'Is the cordless drill easy to handle during use?',
#   'answer': 'The compact size and ergonomic design make it comfortable to use.',
#   'chunk_id': '17'},
#  {'question': 'How long can the cordless drill run without needing a recharge?',
#   'answer': 'The high-capacity battery allows it to work for hours without needing to recharge.',
#   'chunk_id': '18'},
#  {'question': "What are the benefits of the cordless drill's design?",
#   'answer': 'Its compact size and light weight make it great for precision tasks, and the integrated LED light effectively illuminates tight spaces.',
#   'chunk_id': '18'},
#  {'question': 'How long does the battery of this cordless drill last on a single charge?',
#   'answer': 'The lithium-ion battery lasts incredibly long, allowing for numerous tasks to be completed on a single charge.',
#   'chunk_id': '19'},
#  {'question': 'What features help this drill work well in dim lighting?',
#   'answer': 'The integrated LED light provides excellent visibility in dimly lit areas.',
#   'chunk_id': '19'},
#  {'question': 'How durable is the cordless drill?',
#   'answer': 'The cordless drill is incredibly durable, promising longevity.',
#   'chunk_id': '20'},
#  {'question': 'What features help make this drill efficient for various materials?',
#   'answer': 'The advanced torque settings allow users to switch between delicate and tough materials effortlessly.',
#   'chunk_id': '20'},
#  {'question': "How's the battery life on this cordless drill?",
#   'answer': 'The battery life is impressive, allowing for hours of work without needing a recharge.',
#   'chunk_id': '21'},
#  {'question': 'Is it lightweight and easy to handle for long tasks?',
#   'answer': 'Yes, the lightweight design reduces fatigue during long tasks.',
#   'chunk_id': '21'},
#  {'question': 'How well can this cordless drill handle different types of materials?',
#   'answer': 'It has various torque settings that make it easy to handle different types of wood without stripping the screws.',
#   'chunk_id': '22'},
#  {'question': 'Is the battery life of this drill any good?',
#   'answer': 'Yes, the quick-charging battery means minimal downtime, allowing for less waiting time to get back to work.',
#   'chunk_id': '22'},
#  {'question': 'How does this cordless drill handle battery charging times?',
#   'answer': 'The battery charges quickly, allowing for more working time and less waiting time.',
#   'chunk_id': '23'},
#  {'question': 'Is the build quality of this cordless drill good?',
#   'answer': 'Yes, the build quality is top-notch and feels very sturdy.',
#   'chunk_id': '23'},
#  {'question': 'How durable is the cordless drill?',
#   'answer': 'The cordless drill has a durable construction that promises longevity, and the reviewer noted that it has been going strong after six months of use.',
#   'chunk_id': '24'},
#  {'question': 'What features make this cordless drill easy to use?',
#   'answer': 'The drill has variable torque settings for versatility, a comfortable grip, and a well-balanced weight, making it easy on the hands and arms for extended use.',
#   'chunk_id': '24'},
#  {'question': 'How well does this cordless drill handle delicate tasks?',
#   'answer': 'It has advanced torque options that allow for completing intricate tasks without damaging materials.',
#   'chunk_id': '25'},
#  {'question': 'Is this drill tough enough for rough use?',
#   'answer': 'Yes, it is built tough and can handle drops and knocks without issue.',
#   'chunk_id': '25'},
#  {'question': 'How does this cordless drill perform with tough materials?',
#   'answer': 'It features powerful torque settings that can handle everything from metal drilling to masonry work.',
#   'chunk_id': '26'},
#  {'question': 'What makes this drill convenient for continuous use?',
#   'answer': 'The quick-charge feature allows for minimal interruptions, enabling continued work without major downtime.',
#   'chunk_id': '26'},
#  {'question': 'What are the key features of this cordless drill?',
#   'answer': 'The cordless drill features flexible torque settings, solid build quality, and a quick-charging battery.',
#   'chunk_id': '27'},
#  {'question': 'How does the quick-charging battery benefit users?',
#   'answer': 'The quick-charging battery minimizes downtime, allowing for continuous work on various projects.',
#   'chunk_id': '27'},
#  {'question': 'How does this cordless drill perform with different tasks?',
#   'answer': 'This cordless drill performs impressively for a range of tasks, from hanging shelves to drilling into concrete.',
#   'chunk_id': '28'},
#  {'question': 'What features contribute to the drill’s user-friendliness?',
#   'answer': 'The drill is easy to control due to its adjustable torque settings and has a QuickCharge feature that enhances its convenience.',
#   'chunk_id': '28'},
#  {'question': 'How durable is this cordless drill?',
#   'answer': 'The durable construction promises longevity, giving confidence that it will last for years.',
#   'chunk_id': '29'},
#  {'question': 'Can this cordless drill handle delicate tasks?',
#   'answer': 'Yes, it is equipped with advanced torque settings that allow for precision in delicate tasks.',
#   'chunk_id': '29'},
#  {'question': 'How powerful is the motor on this circular saw?',
#   'answer': 'The circular saw features a 15-amp motor that delivers plenty of power, making it easy to cut through 2x4s and even metal pipes.',
#   'chunk_id': '30'},
#  {'question': 'Does this circular saw have any special features for cutting angles?',
#   'answer': 'Yes, it has a bevel capacity of 0-45 degrees, allowing for precise angle cuts which is great for framing projects.',
#   'chunk_id': '30'},
#  {'question': 'How fast does the blade spin on this circular saw?',
#   'answer': 'The blade speed is 6,000 RPM, ensuring smooth and clean cuts.',
#   'chunk_id': '31'},
#  {'question': 'Is this circular saw easy to handle and use for a long time?',
#   'answer': 'Yes, it has an ergonomic handle that reduces fatigue during prolonged use and is lightweight at just 8 pounds.',
#   'chunk_id': '31'},
#  {'question': 'How does the circular saw perform with hardwood?',
#   'answer': 'The combination of the high-torque motor and carbide-tipped blade makes cutting through hardwood a breeze.',
#   'chunk_id': '32'},
#  {'question': 'What features help with changing blades quickly on this saw?',
#   'answer': 'The quick-change blade system is very user-friendly, allowing for blade swaps in seconds.',
#   'chunk_id': '32'},
#  {'question': 'Is this circular saw good for heavy use?',
#   'answer': 'Yes, the circular saw is built for heavy use with durable magnesium construction.',
#   'chunk_id': '33'},
#  {'question': 'What makes this saw safe to use?',
#   'answer': 'The saw features an electric brake that stops the blade almost immediately after the trigger is released.',
#   'chunk_id': '33'},
#  {'question': 'How easy is it to adjust the cutting depth on this circular saw?',
#   'answer': 'The depth adjustment lever is easy to use, allowing precise control over the cut depth.',
#   'chunk_id': '34'},
#  {'question': 'Can this circular saw handle materials other than wood?',
#   'answer': 'Yes, it can cut through metal sheets with no issues at all.',
#   'chunk_id': '34'},
#  {'question': 'How well does this circular saw handle tough materials?',
#   'answer': "The motor performance is impressive, and it doesn't bog down even when cutting through dense materials.",
#   'chunk_id': '35'},
#  {'question': 'What are some cool features of this circular saw?',
#   'answer': 'It has an integrated dust extraction port that connects easily to a shop vac, an over-molded grip for comfort, and a 56-degree bevel capacity which is higher than most saws in this price range.',
#   'chunk_id': '35'},
#  {'question': 'How does the circular saw perform during extended use?',
#   'answer': 'The circular saw features a dual-field motor that keeps the motor cool during extended use.',
#   'chunk_id': '36'},
#  {'question': 'What safety features does this circular saw have?',
#   'answer': 'It has an anti-snag lower guard that is particularly helpful for making thin cuts and a spindle lock for safe and straightforward blade changes.',
#   'chunk_id': '36'},
#  {'question': 'How versatile is the circular saw for different cuts?',
#   'answer': 'The circular saw features adjustable bevel and depth settings, making it very versatile for different types of cuts.',
#   'chunk_id': '37'},
#  {'question': 'What kind of blade comes with the circular saw and how does it perform?',
#   'answer': 'The saw comes with a 16-tooth blade that is sharp and durable, offering smooth performance on plywood and OSB sheets.',
#   'chunk_id': '37'},
#  {'question': 'How durable is the circular saw?',
#   'answer': 'The shoe is made of steel, providing durability.',
#   'chunk_id': '38'},
#  {'question': 'Is the circular saw easy to use for cutting different materials?',
#   'answer': "It's straightforward to adjust the cutting depth and angle, and it performs reliably on both wood and metal.",
#   'chunk_id': '38'},
#  {'question': 'How does this circular saw perform in terms of power and usability?',
#   'answer': "The motor's power-to-weight ratio is one of the best, making the saw powerful and easy to handle.",
#   'chunk_id': '39'},
#  {'question': 'What features enhance the convenience of using this circular saw?',
#   'answer': 'It has an integrated rafter hook for working at heights, a dust chute that directs debris away from the cut line, and a built-in wrench for easy blade changes.',
#   'chunk_id': '39'},
#  {'question': 'How accurate are the cuts made with this circular saw?',
#   'answer': 'The precision laser guide ensures consistently straight cuts and enhances accuracy, allowing for more precise cutting.',
#   'chunk_id': '40'},
#  {'question': 'Is it easy to change the blade on this circular saw?',
#   'answer': 'Yes, the tool-free blade change mechanism allows for quick blade swaps in seconds without needing any additional tools.',
#   'chunk_id': '40'},
#  {'question': 'How powerful is the motor on this circular saw?',
#   'answer': 'The motor is powerful and cuts through hardwood easily.',
#   'chunk_id': '41'},
#  {'question': 'Does this circular saw have any special features for cutting straight?',
#   'answer': 'Yes, it has a bright precision laser guide that is clearly visible in daylight for maintaining a straight line.',
#   'chunk_id': '41'},
#  {'question': 'How durable is this circular saw?',
#   'answer': 'The circular saw is solidly built and feels very durable.',
#   'chunk_id': '42'},
#  {'question': 'What makes changing blades on this circular saw easy?',
#   'answer': 'It has a tool-free blade change mechanism, making blade changes very easy.',
#   'chunk_id': '42'},
#  {'question': 'Is the circular saw easy to use?',
#   'answer': 'Yes, the circular saw features a tool-free blade change system, making it incredibly straightforward to use.',
#   'chunk_id': '43'},
#  {'question': 'How does the circular saw perform with thick materials?',
#   'answer': 'The motor of the circular saw is robust and handles thick materials without any issues.',
#   'chunk_id': '43'},
#  {'question': 'How does the laser guide feature perform on this circular saw?',
#   'answer': 'The laser guide ensures cuts are always straight and accurate, which is particularly useful when making long cuts on large boards.',
#   'chunk_id': '44'},
#  {'question': 'What is notable about the design of the handle on this circular saw?',
#   'answer': 'The ergonomic design of the handle reduces fatigue, even during extended use.',
#   'chunk_id': '44'},
#  {'question': "How's the precision of this circular saw?",
#   'answer': 'The circular saw offers excellent precision, especially with its standout laser guide that provides a clear and accurate line to follow.',
#   'chunk_id': '45'},
#  {'question': 'Is changing the blade easy with this saw?',
#   'answer': 'Yes, the tool-free blade change is incredibly convenient and works as advertised.',
#   'chunk_id': '45'},
#  {'question': 'How accurate are the cuts with this circular saw?',
#   'answer': 'The precision laser guide allows for straighter cuts and enhanced accuracy, eliminating the need for constant measuring and re-aligning.',
#   'chunk_id': '46'},
#  {'question': 'Is the circular saw good for cutting dense materials?',
#   'answer': "Yes, it has plenty of power and doesn't bog down even with denser wood.",
#   'chunk_id': '46'},
#  {'question': "How's the performance of this circular saw with thick materials?",
#   'answer': "The saw's power is sufficient to cut through thick materials without slowing down.",
#   'chunk_id': '47'},
#  {'question': 'Does this circular saw have any special features for cutting accuracy?',
#   'answer': 'Yes, it has a precision laser guide that allows for straighter cuts and enhanced accuracy.',
#   'chunk_id': '47'},
#  {'question': 'How does the circular saw ensure accurate cuts?',
#   'answer': 'It features a precision laser guide that helps maintain straight and accurate cuts.',
#   'chunk_id': '48'},
#  {'question': 'Is it easy to change the blade on this circular saw?',
#   'answer': 'Yes, the blade changes are quick and effortless due to its tool-free blade change mechanism.',
#   'chunk_id': '48'},
#  {'question': 'How good is the precision laser guide on this circular saw for making cuts?',
#   'answer': 'The precision laser guide is very helpful for making straight cuts and provides enhanced accuracy.',
#   'chunk_id': '49'},
#  {'question': 'Is changing the blade on this circular saw a hassle or easy?',
#   'answer': 'The tool-free blade change mechanism allows for quick and easy blade swaps.',
#   'chunk_id': '49'},
#  {'question': 'How does the weight of the circular saw affect its use?',
#   'answer': 'The lower weight makes it extremely easy to handle, especially for users without strong arms.',
#   'chunk_id': '50'},
#  {'question': 'What feature helps keep visibility while cutting?',
#   'answer': 'The integrated dust blower keeps the cutting line visible, ensuring precision with every cut.',
#   'chunk_id': '50'},
#  {'question': 'How does this circular saw handle cutting tasks?',
#   'answer': 'It easily slices through 2x4s and plywood sheets, delivering impressive cutting performance.',
#   'chunk_id': '51'},
#  {'question': 'What feature helps keep the workspace clean while using the saw?',
#   'answer': 'The dust blower keeps the workspace clean and ensures accurate cuts by keeping the line of sight clear.',
#   'chunk_id': '51'},
#  {'question': 'Is this circular saw heavy or light for use over long periods?',
#   'answer': "It's lightweight but powerful, making it ideal for long hours of use without fatigue.",
#   'chunk_id': '52'},
#  {'question': 'Does this circular saw have any features for visibility while cutting?',
#   'answer': 'Yes, the integrated dust blower ensures a clear line of sight and cleaner cuts.',
#   'chunk_id': '52'},
#  {'question': 'What makes this circular saw easy to use for overhead cuts?',
#   'answer': 'The lower weight of the circular saw makes it perfect for overhead cuts and tricky angles.',
#   'chunk_id': '53'},
#  {'question': 'How does the circular saw ensure accuracy during cutting?',
#   'answer': 'The integrated dust blower keeps the line clear, which is essential for accuracy.',
#   'chunk_id': '53'},
#  {'question': 'How does this circular saw handle during use?',
#   'answer': "It's incredibly lightweight, making it easy to maneuver.",
#   'chunk_id': '54'},
#  {'question': 'What is a cool feature of this circular saw?',
#   'answer': 'The integrated dust blower keeps sawdust out of the way, making it safer to use.',
#   'chunk_id': '54'},
#  {'question': 'How does the compact circular saw handle during long use?',
#   'answer': 'Its compact size and low weight make it easy to handle, even for extended periods.',
#   'chunk_id': '55'},
#  {'question': 'What feature keeps the cutting line clear when using the circular saw?',
#   'answer': 'The dust blower is a game-changer, keeping the cutting line clean and visible.',
#   'chunk_id': '55'},
#  {'question': 'How does the weight of the circular saw affect its usability?',
#   'answer': 'The lower weight of the circular saw reduces fatigue during extended use, making it easier to handle.',
#   'chunk_id': '56'},
#  {'question': 'What features help with making accurate cuts?',
#   'answer': 'The integrated dust blower keeps the line of sight clear, which is crucial for making accurate cuts.',
#   'chunk_id': '56'},
#  {'question': 'How does this circular saw perform with hardwoods?',
#   'answer': 'It is powerful enough to handle hardwoods with ease.',
#   'chunk_id': '57'},
#  {'question': 'What feature helps keep the workspace clean when using this saw?',
#   'answer': 'The dust blower works great, keeping the work area clean and ensuring straight cuts.',
#   'chunk_id': '57'},
#  {'question': 'How does the circular saw perform in terms of cutting?',
#   'answer': 'The circular saw delivers excellent cutting performance.',
#   'chunk_id': '58'},
#  {'question': "Is this circular saw easy to handle for someone who isn't very strong?",
#   'answer': 'Yes, its compact design and lower weight make it user-friendly, even for those who are not very strong.',
#   'chunk_id': '58'},
#  {'question': 'How does the weight of this circular saw affect its operation?',
#   'answer': 'The low weight makes it effortless to operate.',
#   'chunk_id': '59'},
#  {'question': 'What feature helps to keep the cutting line visible while using the saw?',
#   'answer': 'The integrated dust blower ensures a clear view of the cutting line.',
#   'chunk_id': '59'},
#  {'question': 'How well does this hammer drill handle tough materials?',
#   'answer': 'This hammer drill can easily drill through concrete, brick, and metal.',
#   'chunk_id': '60'},
#  {'question': 'What features help reduce fatigue during extended use?',
#   'answer': 'The drill has a superior grip design that reduces hand fatigue.',
#   'chunk_id': '60'},
#  {'question': 'How does the hammer drill perform on tough materials?',
#   'answer': 'It is incredibly powerful and handles dense cinder blocks very effectively.',
#   'chunk_id': '61'},
#  {'question': 'What features help reduce hand strain while using this hammer drill?',
#   'answer': 'The ergonomic grip significantly reduces hand strain during long drilling sessions.',
#   'chunk_id': '61'},
#  {'question': 'How does the hammer drill perform on tough materials?',
#   'answer': 'It plows through reinforced concrete with impressive torque.',
#   'chunk_id': '62'},
#  {'question': 'Is the drill mode switch accessible during use?',
#   'answer': 'Yes, the drill mode switch is easily accessible even while wearing gloves.',
#   'chunk_id': '62'},
#  {'question': "What's special about the features of this hammer drill?",
#   'answer': 'The hammer drill has a powerful motor with a dual-mode function for versatile use and anti-vibration technology that reduces hand fatigue during extended use.',
#   'chunk_id': '63'},
#  {'question': 'Is this hammer drill heavy, and does it affect its performance?',
#   'answer': 'Yes, it is a bit heavier than other models, but the power it provides is considered worth the trade-off.',
#   'chunk_id': '63'},
#  {'question': 'How well does the hammer drill perform on tough materials?',
#   'answer': 'It made quick work of drilling into dense concrete slabs.',
#   'chunk_id': '64'},
#  {'question': 'What features help with using the hammer drill in low light?',
#   'answer': 'The LED work light is extremely helpful in dimly lit areas.',
#   'chunk_id': '64'},
#  {'question': 'How comfy is the grip on this hammer drill?',
#   'answer': 'The grip is comfortable and significantly reduces fatigue.',
#   'chunk_id': '65'},
#  {'question': 'Can this hammer drill handle tough materials?',
#   'answer': 'Yes, it has plenty of power for drilling into harder materials like stone and brick.',
#   'chunk_id': '65'},
#  {'question': 'How does the grip of the hammer drill feel during use?',
#   'answer': 'The grip is comfortable for extended use, reducing hand fatigue.',
#   'chunk_id': '66'},
#  {'question': 'What unique features does this hammer drill offer for accuracy?',
#   'answer': 'It has a built-in level that ensures holes are straight.',
#   'chunk_id': '66'},
#  {'question': 'How does the hammer drill handle tough materials like concrete?',
#   'answer': "It goes through solid concrete like it's butter.",
#   'chunk_id': '67'},
#  {'question': 'What makes using the hammer drill comfortable during prolonged use?',
#   'answer': 'The ergonomic design helps reduce hand fatigue significantly.',
#   'chunk_id': '67'},
#  {'question': 'How powerful is the hammer drill?',
#   'answer': 'The hammer drill is incredibly powerful and offers robust drilling power, making it effective for tough materials.',
#   'chunk_id': '68'},
#  {'question': 'What features help reduce hand fatigue with this hammer drill?',
#   'answer': 'The superior grip design of the hammer drill helps reduce hand fatigue during extended projects, compensating for its slightly heavier weight.',
#   'chunk_id': '68'},
#  {'question': 'How powerful is the drilling capability of this hammer drill?',
#   'answer': 'The hammer drill has robust drilling power, capable of drilling into granite with little effort.',
#   'chunk_id': '69'},
#  {'question': 'What features make this hammer drill comfortable to use for long periods?',
#   'answer': 'The superior grip reduces hand fatigue, and the fast charge battery minimizes downtime.',
#   'chunk_id': '69'},
#  {'question': 'How adjustable is the drilling depth on this hammer drill?',
#   'answer': 'The hammer drill features an adjustable depth stop that allows for precise control over the drilling depth, making it easy to achieve the exact depth needed.',
#   'chunk_id': '70'},
#  {'question': 'Is this hammer drill good for different types of jobs?',
#   'answer': 'Yes, this hammer drill has dual-functionality for both drilling and hammering, making it versatile for various applications.',
#   'chunk_id': '70'},
#  {'question': 'How powerful is this hammer drill for drilling through tough materials?',
#   'answer': 'This hammer drill delivers remarkable power, allowing it to drill through concrete with ease.',
#   'chunk_id': '71'},
#  {'question': 'What features make this hammer drill reliable for precision work?',
#   'answer': 'The hammer drill features an adjustable depth stop, which ensures precision in drilling depths.',
#   'chunk_id': '71'},
#  {'question': 'What features make this hammer drill stand out for different projects?',
#   'answer': 'The hammer drill features a dual-function capability, allowing easy switching between drilling wooden panels and hammering masonry.',
#   'chunk_id': '72'},
#  {'question': 'Is the adjustable depth stop really useful for drilling?',
#   'answer': 'Yes, the adjustable depth stop is designed to ensure precise drilling depths and saves time by preventing over-drilling.',
#   'chunk_id': '72'},
#  {'question': 'How well does this hammer drill handle extended use?',
#   'answer': 'The motor is powerful and doesn’t overheat even after extended use.',
#   'chunk_id': '73'},
#  {'question': 'Can this hammer drill do both drilling and hammering?',
#   'answer': 'Yes, it has dual-function capabilities that allow for seamless transition between drilling through drywall and hammering bricks.',
#   'chunk_id': '73'},
#  {'question': 'What makes the adjustable depth stop feature important for this hammer drill?',
#   'answer': 'The adjustable depth stop feature is crucial for achieving precise drilling depths, especially important for cabinetry work.',
#   'chunk_id': '74'},
#  {'question': 'How does the design of this hammer drill aid in long usage?',
#   'answer': 'The rubberized grip design makes it comfortable to use for extended periods without slipping.',
#   'chunk_id': '74'},
#  {'question': 'Is this hammer drill easy to use for home repairs?',
#   'answer': 'Yes, this hammer drill is easy to use and has significant power for various home repairs.',
#   'chunk_id': '75'},
#  {'question': 'Can it handle both drilling and hammering tasks?',
#   'answer': 'Yes, the hammer drill has dual-function capabilities that allow it to switch between drilling holes in the wall and hammering nails quickly.',
#   'chunk_id': '75'},
#  {'question': 'How well does this hammer drill work on hard materials?',
#   'answer': 'It handles tough materials like concrete and brick without any issues.',
#   'chunk_id': '76'},
#  {'question': 'What features help with drilling accuracy?',
#   'answer': 'The adjustable depth stop ensures that all holes are drilled to the exact depth needed.',
#   'chunk_id': '76'},
#  {'question': 'How well does the hammer drill perform for different projects?',
#   'answer': 'The hammer drill performs impressively for both heavy-duty commercial construction and smaller home projects.',
#   'chunk_id': '77'},
#  {'question': 'What features contribute to the accuracy of this hammer drill?',
#   'answer': 'The adjustable depth stop allows for incredibly accurate drilling depths.',
#   'chunk_id': '77'},
#  {'question': 'How precise can this hammer drill get when drilling?',
#   'answer': 'The adjustable depth stop allows for precise drilling depths, ensuring accurate holes every time.',
#   'chunk_id': '78'},
#  {'question': 'Is it easy to switch between drilling and hammering modes?',
#   'answer': 'Yes, the dual-function feature makes it easy to switch from drilling to hammering mode.',
#   'chunk_id': '78'},
#  {'question': 'What features make this hammer drill suitable for tough projects?',
#   'answer': 'The hammer drill is powerful enough to handle brick and concrete, and it has a dual-function feature for both drilling and hammering applications.',
#   'chunk_id': '79'},
#  {'question': 'How does the adjustable depth stop help with drilling?',
#   'answer': 'The adjustable depth stop ensures that users never drill too deep, allowing for precise drilling depths with ease.',
#   'chunk_id': '79'},
#  {'question': 'How good is the precision on this hammer drill?',
#   'answer': 'The hammer drill includes a built-in level that enhances precision for better accuracy during work.',
#   'chunk_id': '80'},
#  {'question': 'Can it handle tough materials like concrete?',
#   'answer': 'Yes, the high-speed steel bits cut through concrete efficiently, making it suitable for heavy-duty tasks.',
#   'chunk_id': '80'},
#  {'question': 'How powerful is the motor on this hammer drill?',
#   'answer': 'The motor is incredibly powerful, allowing for drilling through thick steel beams without any issues.',
#   'chunk_id': '81'},
#  {'question': 'What type of bits come with the hammer drill?',
#   'answer': 'The included high-speed steel bits are top-notch and show no signs of wear even after extensive use.',
#   'chunk_id': '81'},
#  {'question': 'How durable is the hammer drill?',
#   'answer': 'The hammer drill has impressive durable construction and has survived several drops without any damage.',
#   'chunk_id': '82'},
#  {'question': 'Does this hammer drill have any useful features for precise drilling?',
#   'answer': 'Yes, it includes a built-in level that ensures holes are perfectly straight.',
#   'chunk_id': '82'},
#  {'question': 'How well does this hammer drill handle tough materials like brick and concrete?',
#   'answer': 'The hammer drill is excellent for drilling through brick and concrete, making it easy work with high-speed steel bits.',
#   'chunk_id': '83'},
#  {'question': 'Is this hammer drill loud and do I need protection?',
#   'answer': 'Yes, the hammer drill is quite loud, so ear protection is a must.',
#   'chunk_id': '83'},
#  {'question': 'How good is the built-in level feature of this hammer drill?',
#   'answer': 'The built-in level helps maintain accuracy.',
#   'chunk_id': '84'},
#  {'question': 'Is it suitable for tough materials?',
#   'answer': 'Yes, the powerful motor handles tough materials with ease.',
#   'chunk_id': '84'},
#  {'question': 'How well does this hammer drill perform on hard materials?',
#   'answer': 'This hammer drill drills through cement effortlessly, making it suitable for tough materials.',
#   'chunk_id': '85'},
#  {'question': 'What cool feature does this hammer drill have for accuracy?',
#   'answer': 'It includes a built-in level that ensures precise and straight drilling.',
#   'chunk_id': '85'},
#  {'question': 'How well does this hammer drill work on different materials?',
#   'answer': 'It handles various materials effectively, penetrating wood, metal, and concrete effortlessly with high-speed steel bits.',
#   'chunk_id': '86'},
#  {'question': 'Is the hammer drill comfortable to use for a long time?',
#   'answer': 'Yes, the ergonomic handle reduces fatigue, making it comfortable to use during lengthy projects.',
#   'chunk_id': '86'},
#  {'question': 'How does the build quality of the hammer drill feel?',
#   'answer': 'The hammer drill has impressive build quality, feeling sturdy and reliable.',
#   'chunk_id': '87'},
#  {'question': 'Is the hammer drill noisy during operation?',
#   'answer': 'Yes, the hammer drill is a bit on the noisy side, so using ear protection is recommended.',
#   'chunk_id': '87'},
#  {'question': 'How does this hammer drill perform in different situations?',
#   'answer': 'It performs exceptionally well for both home DIY projects and professional work.',
#   'chunk_id': '88'},
#  {'question': 'What features does the hammer drill have for accurate drilling?',
#   'answer': 'It includes a built-in level for enhanced precision and high-speed steel bits that stay sharp.',
#   'chunk_id': '88'},
#  {'question': 'How durable are the bits in this hammer drill?',
#   'answer': 'The high-speed steel bits are extremely durable.',
#   'chunk_id': '89'},
#  {'question': 'Does this hammer drill have any features for precision work?',
#   'answer': 'Yes, it includes a built-in level for enhanced precision.',
#   'chunk_id': '89'},
#  {'question': 'How well do the blades hold up after use?',
#   'answer': 'The high-carbon steel blades hold their edge exceptionally well and require minimal sharpening after repeated use on various hardwoods.',
#   'chunk_id': '90'},
#  {'question': 'Can these chisels be used for detailed work?',
#   'answer': 'Yes, the fine edge allows for precision cuts, making them great for detailed work.',
#   'chunk_id': '90'},
#  {'question': "What's the quality of the chisels in this set?",
#   'answer': 'The chisels are made from high-carbon steel and sharpened to a fine edge for accurate detailing, providing excellent value for their quality.',
#   'chunk_id': '91'},
#  {'question': 'Are the handles of the chisels comfortable to use?',
#   'answer': 'Yes, the handles are comfortable and provide a good grip, which helps reduce hand fatigue during long woodworking sessions.',
#   'chunk_id': '91'},
#  {'question': 'How durable are the chisels in this set?',
#   'answer': 'The chisels are made from high-carbon steel, making them incredibly durable, and they only need to be sharpened once in six months of regular use.',
#   'chunk_id': '92'},
#  {'question': 'What sizes are included in the chisel set?',
#   'answer': 'The set includes various sizes that are perfect for everything from rough carving to fine detail work.',
#   'chunk_id': '92'},
#  {'question': 'How sharp are the chisels in this set right out of the box?',
#   'answer': 'The chisels are outstandingly sharp right out of the box.',
#   'chunk_id': '93'},
#  {'question': 'What can you do with the different sizes of chisels in this set?',
#   'answer': 'The variety of sizes is very practical for various woodworking tasks.',
#   'chunk_id': '93'},
#  {'question': 'How durable are the blades in this wood chisel set?',
#   'answer': 'The blades are made from high-carbon steel, which makes them sharp and durable.',
#   'chunk_id': '94'},
#  {'question': 'What makes these chisels easy to use for beginners?',
#   'answer': 'The ergonomic handles enhance control, making the chisels easy to handle.',
#   'chunk_id': '94'},
#  {'question': 'How do the handles of the chisel set feel during use?',
#   'answer': 'The handles are well-designed, providing excellent control and comfort.',
#   'chunk_id': '95'},
#  {'question': 'Is this chisel set good for detailed work?',
#   'answer': 'Yes, this set is versatile and perfect for both rough and detailed work.',
#   'chunk_id': '95'},
#  {'question': 'How durable are the blades in the wood chisel set?',
#   'answer': 'The blades are made from high-carbon steel, ensuring they stay sharp for a long time.',
#   'chunk_id': '96'},
#  {'question': 'What sizes are included in the wood chisel set?',
#   'answer': 'The set includes a nice variety of sizes, making it suitable for a wide range of projects.',
#   'chunk_id': '96'},
#  {'question': 'How sharp are the chisels in this set?',
#   'answer': 'The chisels are incredibly sharp and maintain their sharpness through extensive use.',
#   'chunk_id': '97'},
#  {'question': 'What material are the blades made from?',
#   'answer': 'The blades are made from high-carbon steel, which allows them to cut through hardwood with ease.',
#   'chunk_id': '97'},
#  {'question': 'How well do the blades of this wood chisel set hold their sharpness?',
#   'answer': 'The blades are sharp and retain their edge well.',
#   'chunk_id': '98'},
#  {'question': 'What materials are the chisels made from?',
#   'answer': 'Each chisel is made from high-carbon steel.',
#   'chunk_id': '98'},
#  {'question': 'How does the high-carbon steel affect the chisel performance?',
#   'answer': 'The high-carbon steel makes a noticeable difference in performance and ease of sharpening.',
#   'chunk_id': '99'},
#  {'question': 'What can you say about the comfort of the chisel handles?',
#   'answer': 'The handles are comfortable and designed for precision work.',
#   'chunk_id': '99'},
#  {'question': "How's the grip on this wood chisel set?",
#   'answer': 'The ergonomic handles provide excellent grip and control, reducing hand fatigue even after hours of use.',
#   'chunk_id': '100'},
#  {'question': 'Are the blades any good for tough materials?',
#   'answer': 'The blades are sharp and durable, effortlessly handling both soft and hard woods.',
#   'chunk_id': '100'},
#  {'question': "How's the balance and comfort of the chisels in this set?",
#   'answer': 'The chisels feel well-balanced and the handles are comfortable to hold.',
#   'chunk_id': '101'},
#  {'question': 'What about the durability of the blades in this chisel set?',
#   'answer': 'The blades have remained sharp and effective despite extensive use in carpentry projects.',
#   'chunk_id': '101'},
#  {'question': 'How comfortable are the handles on this wood chisel set?',
#   'answer': 'The ergonomic design of the handles provides a huge difference in comfort and control.',
#   'chunk_id': '102'},
#  {'question': 'Are the blades of this chisel set durable?',
#   'answer': 'Yes, the blades are designed to withstand heavy use and held up without any chipping or dulling during use.',
#   'chunk_id': '102'},
#  {'question': 'How durable are the blades in this wood chisel set?',
#   'answer': 'The blades are durable and designed to withstand rigorous use.',
#   'chunk_id': '103'},
#  {'question': 'What makes the handles comfortable to use?',
#   'answer': 'The handles are thoughtfully designed to reduce strain on your hands.',
#   'chunk_id': '103'},
#  {'question': 'How durable are the blades in this wood chisel set?',
#   'answer': 'The blades are designed to stay sharp longer than other brands and are durable enough to withstand heavy use.',
#   'chunk_id': '104'},
#  {'question': 'What features make this chisel set comfortable to use?',
#   'answer': 'The set has ergonomic handles that provide superior comfort and control.',
#   'chunk_id': '104'},
#  {'question': 'How good are the chisels in this set for heavy use?',
#   'answer': 'The chisels are of high quality and have remained sharp despite heavy use on various types of wood.',
#   'chunk_id': '105'},
#  {'question': 'What features make these chisels comfortable to use?',
#   'answer': 'The handles are ergonomic, which really saves your hands during extended sessions.',
#   'chunk_id': '105'},
#  {'question': 'How do the blades perform on different types of wood?',
#   'answer': 'The blades cut through both soft and hardwoods with ease.',
#   'chunk_id': '106'},
#  {'question': 'What features make the handles comfortable for use?',
#   'answer': 'The ergonomic handles are perfect for prolonged use.',
#   'chunk_id': '106'},
#  {'question': 'How sharp are the blades on this wood chisel set?',
#   'answer': 'The blades are razor-sharp and carve through wood effortlessly.',
#   'chunk_id': '107'},
#  {'question': 'Are the handles comfortable to use for detailed work?',
#   'answer': 'Yes, the ergonomic handles provide exceptional grip, making intricate work much easier.',
#   'chunk_id': '107'},
#  {'question': 'How well do the blades perform in this wood chisel set?',
#   'answer': 'The blades are sharp and designed for precision cuts, making them perform exceptionally well.',
#   'chunk_id': '108'},
#  {'question': 'What extra features come with the wood chisel set?',
#   'answer': 'The set includes a sharpening guide and blade guards, which are valuable additions.',
#   'chunk_id': '108'},
#  {'question': 'How durable are the blades in the wood chisel set?',
#   'answer': 'The blades are incredibly durable and sharp, designed to withstand heavy use.',
#   'chunk_id': '109'},
#  {'question': 'What features help reduce hand fatigue while using these chisels?',
#   'answer': 'The ergonomic handles are designed to reduce hand fatigue, making them essential for long projects.',
#   'chunk_id': '109'},
#  {'question': 'How comfortable are the handles on the wood chisels?',
#   'answer': 'The hardwood handles offer a premium feel and provide excellent grip, making them comfortable for prolonged use.',
#   'chunk_id': '110'},
#  {'question': 'Are the chisels sharp right out of the box?',
#   'answer': 'Yes, each chisel is sharp right out of the box, ready for use.',
#   'chunk_id': '110'},
#  {'question': 'How sharp are the chisels in this set?',
#   'answer': 'The chisels are super sharp, making them effective for woodworking tasks.',
#   'chunk_id': '111'},
#  {'question': 'Are the handles comfortable for long use?',
#   'answer': 'Yes, the hardwood handles fit comfortably in hands and help reduce fatigue during long sessions.',
#   'chunk_id': '111'},
#  {'question': 'How well do these wood chisels hold their edge?',
#   'answer': 'They hold their edge well.',
#   'chunk_id': '112'},
#  {'question': "What's included in the wood chisel set?",
#   'answer': 'The set includes a variety of sizes and a sturdy protective case.',
#   'chunk_id': '112'},
#  {'question': 'How sharp are the chisels in this set?',
#   'answer': 'The chisels are very sharp and maintain their edge through extensive use.',
#   'chunk_id': '113'},
#  {'question': 'What type of handles does the Wood Chisel Set have?',
#   'answer': 'The chisels have hardwood handles that provide a secure grip.',
#   'chunk_id': '113'},
#  {'question': 'What do people say about the comfort of the handles on this wood chisel set?',
#   'answer': 'The hardwood handles are very comfortable, even during lengthy projects.',
#   'chunk_id': '114'},
#  {'question': 'How does this wood chisel set compare in terms of sharpness and quality?',
#   'answer': 'The sharpness and quality of the steel have really impressed users.',
#   'chunk_id': '114'},
#  {'question': 'Are the handles of the Wood Chisel Set comfortable?',
#   'answer': 'Yes, the hardwood handles are comfortable to hold.',
#   'chunk_id': '115'},
#  {'question': 'How does the quality of the chisels compare in terms of sharpness and durability?',
#   'answer': 'The chisels are very sharp and durable.',
#   'chunk_id': '115'},
#  {'question': 'How sharp are the chisels in this set?',
#   'answer': 'The chisels are razor-sharp.',
#   'chunk_id': '116'},
#  {'question': 'What kind of handles do the chisels have?',
#   'answer': 'The chisels have hardwood handles that provide a sturdy grip.',
#   'chunk_id': '116'},
#  {'question': 'How are the handles on the Wood Chisel Set described?',
#   'answer': 'The hardwood handles are described as comfortable to use.',
#   'chunk_id': '117'},
#  {'question': 'What features does the Wood Chisel Set include for organization?',
#   'answer': 'The set includes a protective case for easy storage and organization.',
#   'chunk_id': '117'},
#  {'question': 'Are the handles on the wood chisel set comfortable to use?',
#   'answer': 'Yes, the hardwood handles are ergonomically designed, making them a pleasure to hold.',
#   'chunk_id': '118'},
#  {'question': 'How do the chisels perform in terms of sharpness and edge retention?',
#   'answer': 'The chisels came sharp and have retained their edge well.',
#   'chunk_id': '118'},
#  {'question': 'How comfy are the handles on these chisels?',
#   'answer': 'The hardwood handles are smooth and comfortable, preventing hand strain even after hours of use.',
#   'chunk_id': '119'},
#  {'question': 'Are these chisels sharp enough for detailed work?',
#   'answer': 'The chisels are extremely sharp and perfect for precision work.',
#   'chunk_id': '119'},
#  {'question': 'What units does this measuring tape use?',
#   'answer': 'The measuring tape features both metric and imperial units, allowing for versatile measurements.',
#   'chunk_id': '120'},
#  {'question': 'Is the tape durable?',
#   'answer': "Yes, the tape is made of a sturdy material that doesn't bend or break easily.",
#   'chunk_id': '120'},
#  {'question': 'How durable is this measuring tape for home projects?',
#   'answer': 'This measuring tape has held up incredibly well during multiple DIY projects.',
#   'chunk_id': '121'},
#  {'question': 'Is the measuring tape easy to use?',
# ...
#   'answer': 'The weight is perfectly balanced, making it comfortable to use for extended periods.',
#   'chunk_id': '461'},
#  {'question': 'How does the magnetic tip feature of the screwdrivers help with usage?',
#   'answer': 'The magnetic tips make it easier to handle screws, especially in awkward positions.',
#   'chunk_id': '462'},
#  {'question': 'What can you say about the durability of this screwdriver set?',
#   'answer': "The robust construction ensures they won't bend or break easily, providing durability and longevity.",
#   'chunk_id': '462'},
#  {'question': 'How effective are the magnetic tips on this screwdriver set?',
#   'answer': 'The magnetic tips are highly effective for convenient screw holding.',
#   'chunk_id': '463'},
#  {'question': 'What materials can this screwdriver set be used on?',
#   'answer': 'This screwdriver set performs exceptionally well on wood, metal, and plastic.',
#   'chunk_id': '463'},
#  {'question': 'What features make this screwdriver set user-friendly?',
#   'answer': 'The screwdriver set includes a magnetic tip for convenient screw holding, and the handles are comfortable to grip even during long projects.',
#   'chunk_id': '464'},
#  {'question': 'How durable is the screwdriver set?',
#   'answer': 'The screwdriver set is made from high-quality forged steel, ensuring durability and preventing the stripping of screws.',
#   'chunk_id': '464'},
#  {'question': 'What makes the magnetic tips of this screwdriver set stand out?',
#   'answer': 'The magnetic tips are a simple feature that makes a huge difference for convenient screw holding.',
#   'chunk_id': '465'},
#  {'question': 'How durable is the build quality of this screwdriver set?',
#   'answer': 'The set is made of forged steel, ensuring excellent build quality and longevity, capable of lasting for years.',
#   'chunk_id': '465'},
#  {'question': 'What features make this screwdriver set handy for difficult tasks?',
#   'answer': 'The screwdriver set includes a magnetic tip, which is very convenient for holding screws, especially in tight or hard-to-reach areas.',
#   'chunk_id': '466'},
#  {'question': 'Is this screwdriver set comfortable to use during extended periods?',
#   'answer': 'Yes, the ergonomic handle is designed to reduce hand fatigue, making it comfortable for long repairs.',
#   'chunk_id': '466'},
#  {'question': 'How durable is the screwdriver set?',
#   'answer': 'The screwdriver set has a forged steel construction that ensures durability and has endured significant use without compromising performance.',
#   'chunk_id': '467'},
#  {'question': 'What makes the screwdrivers easy to use during projects?',
#   'answer': 'The screwdrivers feature magnetic tips that keep screws securely in place, making the job a lot easier.',
#   'chunk_id': '467'},
#  {'question': 'How effective are the handles on this screwdriver set?',
#   'answer': 'The anti-slip handles are comfortable and provide superb grip, making them effective for various tasks.',
#   'chunk_id': '468'},
#  {'question': 'Is this screwdriver set good for delicate tasks?',
#   'answer': "Yes, it's suitable for delicate tasks, allowing for incredible precision.",
#   'chunk_id': '468'},
#  {'question': 'What features make the screwdriver set easy to use?',
#   'answer': 'The screwdriver set has magnetic tips that help keep screws in place and anti-slip handles for better control.',
#   'chunk_id': '469'},
#  {'question': 'Is this screwdriver set suitable for tough projects?',
#   'answer': 'Yes, the screwdriver set is reliable and can be used for both general home repair and professional projects.',
#   'chunk_id': '469'},
#  {'question': 'How durable is this screwdriver set?',
#   'answer': 'This screwdriver set has held up better than most tools, indicating strong durability and quality craftsmanship.',
#   'chunk_id': '470'},
#  {'question': 'What features make this screwdriver set comfortable to use?',
#   'answer': 'The anti-slip handles make the screwdriver set easy to hold for extended periods without discomfort.',
#   'chunk_id': '470'},
#  {'question': "How's the grip on these screwdrivers?",
#   'answer': 'The handles are very well-designed with anti-slip features that prevent slipping during use.',
#   'chunk_id': '471'},
#  {'question': 'Can these screwdrivers handle tough jobs?',
#   'answer': 'Yes, they are durable and fit snugly in screws, making them suitable for both home use and complex tasks like electrical work.',
#   'chunk_id': '471'},
#  {'question': 'How well does this screwdriver set handle delicate tasks?',
#   'answer': 'The fine tips of the screwdriver set are great for delicate work, making it ideal for small electronics repair.',
#   'chunk_id': '472'},
#  {'question': 'What features make this screwdriver set comfortable to use for extended periods?',
#   'answer': 'The anti-slip handles provide excellent grip, while the balanced feel of each screwdriver reduces hand fatigue.',
#   'chunk_id': '472'},
#  {'question': 'How good is the anti-slip feature of this screwdriver set?',
#   'answer': 'The anti-slip feature works well, especially when using oils or lubricants.',
#   'chunk_id': '473'},
#  {'question': 'Is this screwdriver set durable for daily use?',
#   'answer': "They've held up to daily use, and there are no signs of wear on the tips.",
#   'chunk_id': '473'},
#  {'question': 'What makes this screwdriver set stand out?',
#   'answer': 'Its durability and reliability, along with anti-slip handles for a confident grip, make it stand out.',
#   'chunk_id': '474'},
#  {'question': 'Can this screwdriver set handle delicate tasks?',
#   'answer': 'Yes, the anti-slip handles provide precise control during both heavy-duty and delicate tasks.',
#   'chunk_id': '474'},
#  {'question': 'How comfy are the handles on this screwdriver set?',
#   'answer': 'The handles are comfortable and anti-slip, making it easy to use them for long stretches.',
#   'chunk_id': '475'},
#  {'question': 'Can this screwdriver set handle different sizes of screws?',
#   'answer': 'Yes, the variety of screwdriver sizes is handy for tackling everything from small crafts projects to larger home repairs.',
#   'chunk_id': '475'},
#  {'question': 'How do the handles of the screwdriver set feel during use?',
#   'answer': 'The handles are crafted with anti-slip materials, providing a great grip even with sweaty hands.',
#   'chunk_id': '476'},
#  {'question': 'What kinds of jobs can this screwdriver set handle?',
#   'answer': 'The smaller screwdrivers are perfect for eyeglass repairs, while the larger ones are suitable for tougher jobs like door hinge adjustments.',
#   'chunk_id': '476'},
#  {'question': 'How do the handles of this screwdriver set help with control during use?',
#   'answer': 'The anti-slip handles are fantastic for maintaining control, especially during detailed work.',
#   'chunk_id': '477'},
#  {'question': 'Can this screwdriver set be used for detailed projects?',
#   'answer': 'Yes, it can be used for detailed craft projects as well as general tasks like putting together furniture.',
#   'chunk_id': '477'},
#  {'question': 'How does the belt sander perform in woodworking projects?',
#   'answer': 'The belt sander has a powerful 8-amp motor that ensures quick and efficient material removal, significantly speeding up woodworking projects.',
#   'chunk_id': '478'},
#  {'question': 'Is the grip comfortable for extended use?',
#   'answer': 'Yes, the ergonomic grip reduces hand fatigue and remains comfortable to hold even after hours of use.',
#   'chunk_id': '478'},
#  {'question': 'What feature helps keep the workspace tidy?',
#   'answer': 'The dust collection system helps keep the workspace clean.',
#   'chunk_id': '478'},
#  {'question': 'What belt size does this sander have and is it good for big or small projects?',
#   'answer': 'The belt sander has a 3-inch by 21-inch belt size, which is perfect for both small and large projects.',
#   'chunk_id': '479'},
#  {'question': 'Can you adjust the speed of this belt sander?',
#   'answer': 'Yes, the sander features variable speed control that allows you to adjust the speed according to the task at hand.',
#   'chunk_id': '479'},
#  {'question': 'How well does this belt sander finish surfaces?',
#   'answer': 'It leaves a very fine finish during the sanding process.',
#   'chunk_id': '480'},
#  {'question': 'Is the dust bag effective for dust collection?',
#   'answer': 'The dust bag does a decent job of collecting dust, although it could be a bit larger.',
#   'chunk_id': '480'},
#  {'question': 'How does the build quality of this belt sander compare to others?',
#   'answer': 'The build quality is exceptional, and the motor feels more robust compared to others.',
#   'chunk_id': '481'},
#  {'question': 'Is this belt sander good for heavy-duty tasks?',
#   'answer': 'Yes, it is ideal for heavy-duty tasks and tackles them with ease.',
#   'chunk_id': '481'},
#  {'question': 'What makes belt changes easier on this sander?',
#   'answer': 'The quick-release lever for easy belt changes saves a lot of time and works flawlessly.',
#   'chunk_id': '482'},
#  {'question': 'How does this sander handle belt alignment?',
#   'answer': 'The auto-tracking feature means that constant fine-tuning of the belt alignment is not necessary.',
#   'chunk_id': '482'},
#  {'question': 'How effective is this belt sander at removing material?',
#   'answer': 'This belt sander is impressive in its speed and efficiency in removing material.',
#   'chunk_id': '483'},
#  {'question': 'Is the noise level of this belt sander high?',
#   'answer': 'The noise level is relatively low for such a powerful machine.',
#   'chunk_id': '483'},
#  {'question': 'What makes this belt sander versatile?',
#   'answer': 'The included sanding belts of various grits make it adaptable for different projects.',
#   'chunk_id': '484'},
#  {'question': 'How does the design of the belt sander enhance user control?',
#   'answer': 'The adjustable front handle adds another level of control, especially for detailed work.',
#   'chunk_id': '484'},
#  {'question': 'How well does this belt sander handle prolonged use?',
#   'answer': 'The motor does not overheat even with prolonged use, ensuring reliable performance.',
#   'chunk_id': '485'},
#  {'question': 'Is the construction of this belt sander durable?',
#   'answer': 'Yes, the durable construction ensures it can withstand daily use without any issues.',
#   'chunk_id': '485'},
#  {'question': 'How is the belt sander in terms of assembling and setup?',
#   'answer': 'Assembling the sander was a breeze with clear instructions.',
#   'chunk_id': '486'},
#  {'question': 'What features contribute to the comfort of using this belt sander?',
#   'answer': 'The ergonomic design allows for hours of use without discomfort or muscle fatigue.',
#   'chunk_id': '486'},
#  {'question': 'How does this belt sander handle tough materials?',
#   'answer': 'The powerful motor handles tough materials with ease.',
#   'chunk_id': '487'},
#  {'question': 'What about the dust collection on this sander, is it any good?',
#   'answer': 'The dust collection system does a good job, but the bag could be more secure.',
#   'chunk_id': '487'},
#  {'question': 'How does the variable speed control feature help with sanding?',
#   'answer': 'The variable speed control allows for precise sanding based on different project needs.',
#   'chunk_id': '488'},
#  {'question': 'Is the belt sander good at keeping the workspace clean?',
#   'answer': 'Yes, it has an integrated dust collection system that keeps the workspace noticeably cleaner.',
#   'chunk_id': '488'},
#  {'question': 'How does the belt sander handle dust collection?',
#   'answer': 'The belt sander features a very efficient dust collection system that saves time on cleanup.',
#   'chunk_id': '489'},
#  {'question': 'Is the belt sander comfortable to use for long periods?',
#   'answer': 'Yes, the ergonomics are well thought out, making it comfortable to use for extended periods, though it may get a bit warm after prolonged use.',
#   'chunk_id': '489'},
#  {'question': 'How good is the speed control on this belt sander?',
#   'answer': 'The speed control feature is very intuitive, allowing for adjustments based on the material being worked on.',
#   'chunk_id': '490'},
#  {'question': 'Does this belt sander keep the workspace clean?',
#   'answer': 'Yes, the integrated dust collection system works surprisingly well, keeping dust to a minimum.',
#   'chunk_id': '490'},
#  {'question': 'How flexible is the sanding process with this belt sander?',
#   'answer': 'The belt sander features variable speed control, allowing for great flexibility to customize the sanding process based on project needs, whether for delicate wood pieces or more robust materials.',
#   'chunk_id': '491'},
#  {'question': 'Is the dust collection system effective on this belt sander?',
#   'answer': 'Yes, the integrated dust collection feature is quite effective, making cleanup much easier in the workspace.',
#   'chunk_id': '491'},
#  {'question': 'How does the speed setting work on this belt sander?',
#   'answer': 'The belt sander features adjustable speed settings that provide control over each project.',
#   'chunk_id': '492'},
#  {'question': 'Is there a dust collection feature?',
#   'answer': 'Yes, it has a built-in dust collection system that significantly reduces cleanup time.',
#   'chunk_id': '492'},
#  {'question': 'How does the belt sander handle different materials?',
#   'answer': 'The belt sander features variable speed control, which allows for customizing the sanding process based on project needs, making it effective for achieving different finishes on various materials.',
#   'chunk_id': '493'},
#  {'question': 'Is the belt sander good at keeping the workspace clean?',
#   'answer': 'Yes, the integrated dust collection system is quite efficient and helps maintain a clean workspace.',
#   'chunk_id': '493'},
#  {'question': 'How does the speed control work on this belt sander?',
#   'answer': 'The speed control is seamless, enhancing the versatility of the sander.',
#   'chunk_id': '494'},
#  {'question': 'Is there anything about the grip that could be better?',
#   'answer': 'Yes, it could benefit from a softer grip for easier handling.',
#   'chunk_id': '494'},
#  {'question': 'How user-friendly is the variable speed control on the belt sander?',
#   'answer': 'The variable speed control is very user-friendly, allowing for precise adjustments depending on the project.',
#   'chunk_id': '495'},
#  {'question': "What's the deal with the dust collection system on this sander?",
#   'answer': 'The dust collection system does its job well, keeping the garage free from excessive sawdust.',
#   'chunk_id': '495'},
#  {'question': 'How well does the dust collection system work on this belt sander?',
#   'answer': 'The dust collection system keeps the work area much cleaner than previous sanders.',
#   'chunk_id': '496'},
#  {'question': 'Is the weight of this belt sander a concern?',
#   'answer': 'The weight might be an issue for some users, but the tool itself feels solid and rugged.',
#   'chunk_id': '496'},
#  {'question': 'How does the speed feature of the belt sander affect its performance?',
#   'answer': 'The variable speed feature is very beneficial for achieving a smooth finish on different materials.',
#   'chunk_id': '497'},
#  {'question': 'Is the belt sander heavy, and does it affect usability?',
#   'answer': "It's a bit on the heavier side, but that contributes to its stability and control during use.",
#   'chunk_id': '497'},
#  {'question': 'Is the belt sander lightweight and easy to handle?',
#   'answer': 'Yes, the belt sander is lightweight enough for single-handed use, making it easy to maneuver in tight spaces.',
#   'chunk_id': '498'},
#  {'question': 'How does the sander perform on tough materials?',
#   'answer': 'The compact design of the belt sander is robust enough to handle tough jobs, such as sanding oak effortlessly.',
#   'chunk_id': '498'},
#  {'question': 'How does the belt sander perform over long periods of use?',
#   'answer': 'It has a robust motor that handles continuous use without overheating, allowing for longer work sessions without fatigue.',
#   'chunk_id': '499'},
#  ...]

# %% [markdown]
# ## Set Up Evaluation
#
# Load the evaluation questions into a structured format.

# %%
from pydantic import BaseModel


class EvalQuestion(BaseModel):
    question: str
    answer: str
    chunk_id: str

# %%
from pydantic import TypeAdapter

eval_questions = TypeAdapter(list[EvalQuestion]).validate_python(synthetic_questions)

# %% [markdown]
# Build a simple search function

# %%
def run_simple_request(q: EvalQuestion, n_return_vals=5):
    results = (
        reviews_table.search(q.question).select(["id"]).limit(n_return_vals).to_list()
    )
    return [str(q.chunk_id) == str(r["id"]) for r in results]

# %% [markdown]
# Now do the benchmarking. For simplicity, we just compare retrieval sizes with a simple semantic search in this cell.

# %%
def score(hits):
    # This implementation assumes
    n_retrieval_requests = len(hits)
    total_retrievals = sum(len(l) for l in hits)
    true_positives = sum(sum(sublist) for sublist in hits)
    precision = true_positives / total_retrievals if total_retrievals > 0 else 0
    recall = true_positives / n_retrieval_requests if n_retrieval_requests > 0 else 0
    return {"precision": precision, "recall": recall}


def score_simple_search(n_to_retrieve: List[int]) -> Dict[str, float]:
    # parallelize to speed this up 5-10X
    with ThreadPoolExecutor() as executor:
        hits = list(
            executor.map(lambda q: run_simple_request(q, n_to_retrieve), eval_questions)
        )
    return score(hits)


k_to_retrieve = [5, 10, 20]
scores = pd.DataFrame([score_simple_search(n) for n in k_to_retrieve])
scores["n_retrieved"] = k_to_retrieve
scores
# Out:
#    precision    recall  n_retrieved
# 0   0.099206  0.496029            5
# 1   0.068785  0.687847           10
# 2   0.044003  0.880064           20

# %% [markdown]
# If you have Cohere set up, you can compare these results to the results with a reranker.
#
# If you aren't familiar with rerankers, don't worry. We will cover them in upcoming lessons.

# %%
import cohere
cohere_api_key = os.environ["COHERE_API_KEY"]

# %%
def run_reranked_request(q: EvalQuestion, n_return_vals=5, n_to_rerank=50) -> List[bool]:
    # First, get more results than we need
    initial_results = reviews_table.search(q.question) \
        .select(["id", "review"]) \
        .limit(n_to_rerank) \
        .to_list()
    
    # Prepare texts for reranking
    texts = [r["review"] for r in initial_results]
    
    # Rerank using Cohere
    co = cohere.Client(cohere_api_key)
    reranked = co.rerank(
        query=q.question,
        documents=texts,
        top_n=n_return_vals
    )
    
    # Map reranked results back to original IDs
    reranked_ids = [initial_results[r.index]["id"] for r in reranked.results]
    return [str(q.chunk_id) == str(r) for r in reranked_ids]

def score_reranked_search(n_to_retrieve: List[int], n_to_rerank: int = 50) -> Dict[str, float]:
    with ThreadPoolExecutor() as executor:
        hits = list(executor.map(
            lambda q: run_reranked_request(q, n_to_retrieve, n_to_rerank), 
            eval_questions
        ))
    return score(hits)

# %%
k_to_retrieve = [5, 10, 20]
reranked_scores = pd.DataFrame([score_reranked_search(n) for n in k_to_retrieve])
reranked_scores["n_retrieved"] = k_to_retrieve
print(reranked_scores)
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[39], line 2
#       1 k_to_retrieve = [5, 10, 20]
# ----> 2 reranked_scores = pd.DataFrame([score_reranked_search(n) for n in k_to_retrieve])
#       3 reranked_scores["n_retrieved"] = k_to_retrieve
#       4 print(reranked_scores)
#
# Cell In[39], line 2, in <listcomp>(.0)
#       1 k_to_retrieve = [5, 10, 20]
# ----> 2 reranked_scores = pd.DataFrame([score_reranked_search(n) for n in k_to_retrieve])
#       3 reranked_scores["n_retrieved"] = k_to_retrieve
#       4 print(reranked_scores)
#
# Cell In[30], line 25, in score_reranked_search(n_to_retrieve, n_to_rerank)
#      23 def score_reranked_search(n_to_retrieve: List[int], n_to_rerank: int = 50) -> Dict[str, float]:
#      24     with ThreadPoolExecutor() as executor:
# ---> 25         hits = list(executor.map(
#      26             lambda q: run_reranked_request(q, n_to_retrieve, n_to_rerank),
#      27             eval_questions
#      28         ))
#      29     return score(hits)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# Cell In[30], line 26, in score_reranked_search.<locals>.<lambda>(q)
#      23 def score_reranked_search(n_to_retrieve: List[int], n_to_rerank: int = 50) -> Dict[str, float]:
#      24     with ThreadPoolExecutor() as executor:
#      25         hits = list(executor.map(
# ---> 26             lambda q: run_reranked_request(q, n_to_retrieve, n_to_rerank),
#      27             eval_questions
#      28         ))
#      29     return score(hits)
#
# Cell In[30], line 13, in run_reranked_request(q, n_return_vals, n_to_rerank)
#      11 # Rerank using Cohere
#      12 co = cohere.Client(cohere_api_key)
# ---> 13 reranked = co.rerank(
#      14     query=q.question,
#      15     documents=texts,
#      16     top_n=n_return_vals
#      17 )
#      19 # Map reranked results back to original IDs
#      20 reranked_ids = [initial_results[r.index]["id"] for r in reranked.results]
#
# File ~/code/systematically-improving-rag/.venv/lib/python3.11/site-packages/cohere/base_client.py:1614, in BaseCohere.rerank(self, query, documents, model, top_n, rank_fields, return_documents, max_chunks_per_doc, request_options)
#    1610     raise ClientClosedRequestError(
#    1611         typing.cast(ClientClosedRequestErrorBody, construct_type(type_=ClientClosedRequestErrorBody, object_=_response.json()))  # type: ignore
#    1612     )
#    1613 if _response.status_code == 500:
# -> 1614     raise InternalServerError(
#    1615         typing.cast(typing.Any, construct_type(type_=typing.Any, object_=_response.json()))  # type: ignore
#    1616     )
#    1617 if _response.status_code == 501:
#    1618     raise NotImplementedError(
#    1619         typing.cast(NotImplementedErrorBody, construct_type(type_=NotImplementedErrorBody, object_=_response.json()))  # type: ignore
#    1620     )
#
# InternalServerError: status_code: 500, body: {'message': 'internal server error, this has been reported to our developers. id 847f40c3-73e7-4006-bed3-adde87c6a905'}

# %%
reranked_scores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 reranked_scores
#
# NameError: name 'reranked_scores' is not defined
